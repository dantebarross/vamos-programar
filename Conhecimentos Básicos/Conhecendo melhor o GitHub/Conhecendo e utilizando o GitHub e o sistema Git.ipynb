# %% [markdown]
#  <a name="intro"></a>
# # Conhecendo melhor o GitHub
#
# ## Sumário
# 1. [Git e GitHub, são a mesma coisa?](#git1)
# 2. [Mas como funciona o sistema do Git?](#git2)
# 3. [Tudo bem, e onde entra o GitHub nisso?](#git3)
# 4. [Instalando o Git, o GitHub Desktop e o IDE (Windows)](#git4)
# 5. [Instalando o Git, o GitHub Desktop e o IDE (Linux)](#git5)
# 6. [GitHub Desktop e criando um repositório](#git6)
# 7. [Utilizando o GitHub Desktop e os IDEs](#git7)
# 8. [Fazendo o commit e push de alterações](#git8)
# 9. [Clonando um repositório já existente](#git9)
#
#
#
#
# ### 1. Git e GitHub, são a mesma coisa? <a name="git1"></a> [🠡](#intro)
#
# Se você já se deparou com os temos **Git** e **GitHub**, talvez tenha percebido que eles não são a mesma coisa.
#
# O **Git** é um software utilizado para controlar a versão (_Sistema de Controle de Versão_, ou VCS) de um código ou de projetos inteiros. Pode ser utilizado individualmente ou em equipe, através do terminal ou da interface. Exemplo: você já está na terceira versão (3.0) de um programa, e utilizou o Git em todas as etapas de programação. O código da versão 1.0 precisa ser resgatado? Com o Git você **pode** realizar esse resgate, o que torna o desenvolvimento do projeto muito mais seguro, além de outras vantagens como o trabalho em equipe, todos ao mesmo tempo em um mesmo projeto! É uma questão de organização, saber quem fez o que, o que mudou, nos mínimos detalhes. Se a mudança ocasionou algum bug, o retorno a uma versão anterior pode ser feito. Para que o sistema dê mais certo ainda, as mudanças podem e devem ser comentadas.
#
# Já o **GitHub** é uma plataforma que procura integrar o sistema acima (ser um repositório de projetos no estilo VCS), mas sua intenção vai além disso! Aqui no GitHub, existe a proposta de disponibilizar seu código para o mundo, reunir programadores para que ajudem a melhorar projetos e também como rede social. As formas de utilizar o GitHub são diversas. Aqui, por exemplo, tento passar um pouco do meu conhecimento para quem deseja realizar o básico e um pouco mais, além de compreender cada etapa no processo de desenvolvimento. O GitHub pode inclusive ser visto como uma espécie de **LinkedIn dos programadores**. É isso mesmo! Aqui você exibe seus projetos, fala um pouco mais de si mesmo e pode ser contatado a qualquer instante por recrutadores.
#
# ### 2. Mas como funciona o sistema do Git? <a name="git2"></a> [🠡](#intro)
#
# Aqui, nós vamos falar sobre a parte de Versionamento desses sistemas, como funciona e como podem ser utilizados.
#
# Utilizando o sistema do Git, o processo que acontece pode ser simplificado abaixo:
# 1. Criação de um **repositório**, seja no seu próprio computador ou em Nuvem (no GitHub, por exemplo);
# 2. Ao desenvolver um código, realizar o **commit** (uma equipe toda pode realizar seus commits nesse repositório, há a possibilidade de adicionar e restringir acessos). Ao realizar um commit, você fará o armazenamento daquela versão do código ao seu repositório local (normalmente em sua máquina). Também serão armazenadas informações de **quem** fez o commit, **o que** adicionou/removeu/substituiu, **quando** fez isso e **quais** os comentários do commit fez, se houver.
# 3. Realizar o push da versão de seu código e informações para o repositório remoto (só aqui as alterações estarão disponíveis para a equipe), ou seja, para o repositório da equipe (**que pode muito bem estar no GitHub**).
#
# Um bom exemplo para entender a complexidade e vantagem de um sistema de versionamento como o Git:
# Se você e outros colegas estão trabalhando no mesmo código, primeiramente devem se comunicar. Depois de realizadas as alterações, ao realizar o commit e o push, o Git fará com que os conflitos sejam os mínimos possíveis. Se você alterou apenas o final do código, ou adicionou comentários, somente essas alterações serão consideradas. Caso seu colega venha a dar commit e push depois disso, o código dele será adicionado apenas onde foi alterado. O resultado final é: as alterações dele e as suas alterações, juntas! Se vocês alteraram a mesma linha de código, as duas alterações serão mostradas, provavelmente como forma de alerta, em uma cor diferente, através de uma notificação, etc.
#
# É claro, devemos evitar ao máximo tais mudanças! Futuramente talvez tenhamos uma plataforma Git com alterações ao vivo, para que duas ou mais pessoas trabalhem na exata mesma versão de código, com commits e comentários em equipe, rodando em uma espécie de repositório compartilhado.
#
#
# ### 3. Tudo bem, e onde entra o GitHub nisso? <a name="git3"></a> [🠡](#intro)
# Se você usou o GitHub para armazenar seus programas, percebeu que ele serve como repositório de armazenamento (público e privado), e também que é muito melhor do que o Google Drive ou qualquer outro serviço de nuvem, pois além de armazenar, o GitHub também exibe o código em todas as linguagens de programação do mercado.
#
# Além de servir de repositório de armazenamento e de todas as vantagens citadas no começo desse documento, o GitHub **pode ser utilizado em conjunto com o sistema Git**, onde o **Git** servirá como seu **repositório local**, (sua máquina) e o **GitHub** será o **repositório remoto**, funcionando em nuvem e possibilitando o trabalho em equipe dentro de uma plataforma muito amigável, inclusive possibilitando que pessoas de fora contribuam com sugestões e com alterações no código. Os repositórios públicos do GitHub são **ilimitados**. Os privados também, porém aceitam apenas três ou menos colaboradores.
#
# Se por acaso não curtiu o GitHub por qualquer aspecto, existem outros que funcionam de forma muito parecida (como um repositório remoto para trabalhar em equipe através do Git):
# 1. GitLab - https://about.gitlab.com/
# 2. Kallithea - https://kallithea-scm.org/
# 3. Gogs - https://gogs.io/
# 4. Phabricator - https://www.phacility.com/phabricator/
# 5. Bitbucket - https://bitbucket.org/
#
# Minha experiência pessoal foi apenas com o GitLab, e não tenho reclamações. A gente sabe como os culpados por erros geralmente são de quem está atrás das telas, rsrsrs.

# %% [markdown]
# ### 4. Instalando o Git, o GitHub Desktop e o IDE (Windows) <a name="git4"></a> [🠡](#intro)
# Para instalar o sistema Git, basta acessar o site oficial na sessão downloads e escolher seu SO: https://git-scm.com/downloads
#
# Uma das maneiras mais amigáveis de se utilizar o Git é através dos GUI Clients, ou seja, softwares visuais, clicáveis. Sem eles, o Git funciona através da Command Line/Terminal de seu computador.
#
# No site oficial do Git, na sessão GUI Clients, podemos encontrar o GitHub Desktop. Por enquanto só possui suporte para Windows e Mac, mas você também pode procurar outros GUI Clients para seu Linux (**na sessão do Linux, ensinaremos um outro jeito de instalar o GitHub Desktop!**)
#
# Sessão das GUI Clients - https://git-scm.com/downloads/guis
# Site oficial do GitHub Desktop - https://desktop.github.com/
#
# **ATENÇÃO!!**: Antes de instalar o GitHub Desktop, se você não tiver uma conta GitHub, cadastre-se na plataforma!
#
# Podemos reparar na interessante definição do GitHub Desktop em seu site oficial:
#
# "Focus on what matters instead of fighting with Git. Whether you're new to Git or a seasoned user, GitHub Desktop simplifies your development workflow"
#
# Você também precisará de um editor de códigos. Pode ser até mesmo o Jupyter Notebook, porém para ter uma melhor integração com o GitHub, utilizaremos uma IDE que já tenha **controle Git incorporado**.
#
# O **PyCharm** é o meu IDE preferido, e sempre recomendo! Olharemos atentamente neste guia para ele e para o **VS Code**:
#
# Baixe a versão Community do PyCharm - https://www.jetbrains.com/pt-br/pycharm/download/
#
# Baixe a versão Stable do VS Code - https://code.visualstudio.com/

# %% [markdown]
# ### 5. Instalando o Git, o GitHub Desktop e o IDE (Linux) <a name="git5"></a> [🠡](#intro)
# O Git foi originalmente feito para Linux. Isso mesmo! Linus Torvalds, **o próprio criador do Linux**, desenvolveu também o **Git** por conta de uma **briga feia**. Pra saber mais, você pode acessar a história no Wikipedia https://pt.wikipedia.org/wiki/Git.
#
#
# Aberta sua distribuição Linux, você provavelmente já tem acesso ao Terminal e à senha de super usuário (sudo). Abra-o e realize os comandos abaixo:
#
# ``
# sudo apt update
# sudo apt upgrade -y
# sudo apt install git -y
# ``
#
#
# **DICAS!**:
# - O "-y" faz com que não precisemos ficar confirmando com o "y" de _yes_ toda hora.
# - Para checar sua versão git, utilize o comando **git --version**.
#
# Se ainda não tem, instale um IDE para editarmos os códigos e acessarmos o projeto. Recomendo os dois abaixo.
# 1. A versão Community do PyCharm - https://www.jetbrains.com/pt-br/pycharm/download/
# 2. A versão Stable do VS Code - https://code.visualstudio.com/
#
# No Linux ainda não é possível instalar o software GitHub Desktop diretamente do site oficial (mas veremos outro método **agora**).
# Para encontrar o instalador, visitaremos o repositório **desktop** do usuário shiftkey, criador desse método: https://github.com/shiftkey/desktop
#
# O arquivo de instalação está no link a seguir, página dos _Last releases_: https://github.com/shiftkey/desktop/releases
#
# Clique na última versão (_release_) e escolha o arquivo de instalação de sua distribuição Linux (se você não souber qual é, arrisque o arquivo _.deb_, para as distribuições baseadas no Debian).
#
# A instalação deu certo? Siga o passo a passo na sessão a seguir!

# %% [markdown]
# ### 6. GitHub Desktop e criando um repositório <a name="git6"></a> [🠡](#intro)
# No processo de instalação do GitHub Desktop, faça o _Sign In_ em sua conta do GitHub.
#
# Ao abrir o software, já nos deparamos com algumas opções das mais utilizadas:
#
# <img src="images/options github desktop.png"  alt="GitHub Desktop" width=600/>
#
# As opções são:
# 1. Criar um repositório tutorial, onde você passará por um rápido guia para aprender as principais funções
# 2. Clonar um repositório da Internet (pode ser seu ou até mesmo de outra pessoa!)
# 3. Criar um novo repositório em seu HD, com isso você criará uma pasta no computador que será associada a um repositório no GitHub.
# 4. O mesmo que antes, porém agora você pode escolher uma pasta, independente de estar vazia ou com projetos.
#
# Vou criar o repositório em que será inserido *esse* guia, pois estava aguardando esse momento! O padrão é criar um repositório privado, que só você poderá acessar (ou quem tiver permissão no futuro).
#
# Ao clicar em  necessário dar um nome a ele, descrição, inserir a pasta do projeto e uma licença. Recomendo escolher a licença MIT.
#
# Acabamos de criar um **repositório local**, ou seja, ele ainda não aparece em seu repositório online no site do GitHub. Para que isso aconteça, precisamos escolher a opção **Publish repositório**.
#
# ### 7. Utilizando o GitHub Desktop e os IDEs <a name="git7"></a> [🠡](#intro)
# Repositório criado e publicado no GitHub. Ao baixar e instalar o VS Code ou o PyCharm, clique na aba _Files_ (ou _Arquivo_) e vá em _Open Folder_ (ou _Abrir Pasta_). Selecione a pasta que foi criada dentro do GitHub Desktop. O seu **repositório local** será reconhecido e aberto dentro da IDE. Podemos acessar as mudanças e também as diferentes _branchs_ de seu repositório nas setas mostradas abaixo (no VS Code).
#
# <img src="images/ide git.png"  alt="IDE Git" width=200/>
#
#
# Clicando na opção das três bolinhas, você perceberá que o **VS Code** consegue realizar commits e várias outras funções incluindo o push, direto do IDE! Clique em alguma das opções e uma janela para login no GitHub será aberta. É uma opção viável.
#
# Ao abrir o repositório local no **PyCharm**, ele também detectará o sistema Git. Realize o commit de suas alterações e clique na opção **Push**. Uma janela para logar no GitHub aparecerá. Desse modo, **você não precisa acessar o GitHub Desktop toda vez que quiser realizar um commit, ou push, ou trocar de branch**.
#
#
#
# Opções de cima            |  Branchs
# :-------------------------:|:-------------------------:
# <img src="images/pycharm git1.png"  alt="Commit Git" width=250/> | <img src="images/pycharm git2.png"  alt="Commit Git" width=250/>
#
# **BONUS:** Algumas dicas para o VS Code:
# 1. Abra-o e clique no ícone mostrado abaixo, ou pressione _Ctrl + Shift + X_ para abrir a sessão _Extensões_.
# <img src="images/vscode extensions.png"  alt="Extensions" width=500/>
# 2. No campo de digitação que apareceu, podemos procurar pelo termo chave "Portuguese" para instalar um pacote de língua portuguesa e mudar a língua do software. Ao clicar em instalar, reinicie o VS Code.
# 2. Outra dica é clicar na aba _Arquivo_ ou _File_ e ativar o Save automático.
#
#
# Feito isso, todos os arquivos que criarmos ou editarmos, seja através do IDE ou manualmente, serão detectados pelo Git e poderão ser "commitadas", e "pushadas" para o seu repositório online do GitHub.
#
# ### 8. Fazendo o commit e push de alterações <a name="git8"></a> [🠡](#intro)
#
# Na imagem abaixo, podemos observar que eu realizei a correção de pontuação, salvei o arquivo e, ao clicar em _Fetch origin_ dentro do meu repositório no GitHub Desktop, a pequena alteração foi localizada!
#
# <img src="images/alteracao_fetch.png"  alt="Alteração no Git" width=600/>
#
# Para confirmar as alterações, podemos criar em Commit. Caso queiramos descartar quaisquer alterações, ou ignorar o arquivo para que suas alterações não sejam notificadas nem Commitadas pelo Git, clique com o botão direito no arquivo desejado. As opções estão indicadas na imagem abaixo.
#
# <img src="images/commit_or_not.png"  alt="Commit Git" width=250/>
#
# Para "commitar", escolha um título da alteração e uma descrição do que foi feito. O servidor remoto do GitHub só receberá as alterações após ser feito o **Push**. Para isso, no GitHub Desktop clique no botão **Push origin** ou aperte _Ctrl + P_.
#
# Voilà! Suas alterações agora podem ser vistas no repositório online. Quaisquer alterações que forem feitas em seu projeto no repositório local (na pasta de seu computador) aparecerão como alterações. Você pode inclusive utilizar o Jupyter Notebook, cujo tutorial já temos aqui em meu repositório de guias.
#
# Você fez algum alteração diretamente no repositório online do GitHub ou seu colega também fez alguma alteração? **Elas só serão exibidas quando atualizar o repositório através do botão _Fetch origin_ já visto anteriormente**. Se algo foi alterado e commitado no repositório online e seu repositório local ainda não possuir a alteração, o Git acusará isso e, para realizar a atualização, clique no botão _Pull origin_ ou aperte _Ctrl + Shift + P_. Assim seu repositório local estará exatamente igual o repositório online.

# %% [markdown]
# ### 9. Clonando um repositório já existente <a name="git9"></a> [🠡](#intro)
# Se um repositório está público (ou você tem acesso a ele mesmo privado), existe algumas formas de clona-lo, transferindo para uma pasta de seu computador em formato de repositório local. Ao utilizar sua IDE e o GitHub Desktop, talvez já tenha se deparado com a opção Clonar Repositório, vamos fazer isso através do GitHub Desktop.
#
# Para isso, primeiro você deve abrir o repositório que deseja clonar através do GitHub (em outros sistemas como o GitLab também existe essa possibilidade! Ambos são sistemas Git).
#
# Clique no botão indicado abaixo. Todas as opções são válidas para fazer o download do repositório, porém para clona-lo como um sistema Git, não basta apenas realizar o download em Zip. Clique em **Open with GitHub Desktop**. Aceite a permissão se for notificado!
#
# <img src="images/clone repository.png"  alt="Clone Repository" width=700/>
#
# Uma janela contendo a URL do repositório será aberta, bem como o path que pode ser alterado.
#
# Outro jeito de fazer isso dentro do GitHub Desktop é o de clicar em _File_ e em _Clone Repository_ ou apertar _Ctrl + Shift + O_. Lá, você seleciona a pasta desejada e cola a URL do repositório GitHub.
#
# Pronto! Você já pode abrir a pasta no seu IDE, rodar os códigos do programa, acessar e modificar arquivos e subir do seu repositório local para seu repositório online do GitHub. **ATENÇÃO: NUNCA FALE QUE É SEU, O QUE NÃO É SEU**.
#
# Clonar o repositório de alguém, modificá-lo e realizar o push para o seu próprio repositório não significa que o programa agora é seu. Se tem objetivo de melhorar o código, cite o criador, a URL do repositório original e informe o que foi alterado ao publicar.
#
# Lembre-se que **um programa pode ser de código aberto, mas a propriedade intelectual de quem o criou existe e o crédito deve ser dado, incluindo todos seus códigos, programas e repositórios**!
#
# Veja as licenças mais utilizadas no site https://choosealicense.com/licenses/.

# %% [markdown]
# ### 10. Entendendo e utilizando branchs
# #### 10.1 O que é branch e para que serve?
# _Branch_ em inglês significa **ramo**, e a simbologia dos ramos de uma árvore ajuda a entender o que é e como funciona esse sistema.
#
# Assim que um repositório é criado, uma _branch_ é criada por padrão: ela é a **raíz** de seu projeto, ou _branch_ **master**, você certamente já se deparou com essa palavra.
#
# Acontece que, dessa branch raíz de seu repositório, podem ser criadas subraízes. Parece mais complexo, porém em projetos gigantes elas ajudam muito!
#
# Pense no caso em que um projeto possui diversas equipes trabalhando em cima de um mesmo programa: designers, cientistas de dados, desenvolvedores. Por conta da grandeza do projeto, é viável que branchs sejam criadas sempre que um trabalho conseguir se desenvolver individualmente, sem precisar das atualizações constantes.
#
# Outro caso é o de alguém que precisa de um código funcionando, porém já existe outra pessoa realizando alterações (e bugando) o mesmo. Se isso ocorre com frequência, faz sentido separar em mais uma branch.
#
# Cada branch será muito parecida com suas irmãs, pois normalmente possuem as mesmas dependências e precisam dos mesmos códigos para funcionar.
#
# Provavelmente você não precisará de tantas branchs para seus repositórios, mas **é recomendável que crie uma branch teste**.
#
# #### 10.2 Quando utilizar uma branch nova
# Imagina essa situação: seu código está funcionando bem, porém você decide fazer uma alteração e buga ele. Quer manter o trabalho do jeito que está, porém se der push para a raíz, ela ficará bugada para todos que acessarem o código, e poderá gerar uma confusão, precisando de retorno de versionamento caso tudo dê errado.
#
# Ou outro caso: seu código está ótimo e agora é hora de trabalhar no desenvolvimento do aplicativo. Uma branch será criada, com o repositório duplicado especialmente para isso, deixando o repositório raíz intacto. Se cansar de produzir o design e quiser deixar estagnado ou se decidir excluir o trabalho, a branch não afetará o ramo principal.
#
# Ao finalmente terminar o trabalho de uma _branch_, o melhor jeito de juntá-lo com o ramo principal é através da opção **merge**. Lembra quando falamos de como duas pessoas podem trabalhar em um mesmo código ao mesmo tempo e de como o sistema Git tenta minimizar ao máximo quaisquer conflitos que existam? Isso também valerá ao realizar o **merge** de duas _branchs_.
#
# **Um merge só será completo após resolvermos quaisquer conflitos que existam, e o Git nos apontará todos eles**.
#
# #### 10.3 Como criar uma branch nova
# Existem algumas formas de criar uma branch nova. Uma delas é através dos softwares que já temos. Seu GitHub Desktop e IDE provavelmente já estão conectados ao seu repositório local Git e ao GitHub.
#
# Dentro do seu repositório local no GitHub Desktop, clique na opção _Current branch_ e vá em _New branch_, como mostra a imagem. Dê um nome para ela. Se você tiver alterações não commitadas na _branch_ master, transfira-as para a nova _branch_ clicando na opção _Bring my changes to new branch_.
#
# <img src="images/create branch.png"  alt="New Branch" width=500>
#
# Clique em _Publish branch_ para que ela seja exibida em seu GitHub. Para isso, entre no repositório e clique seguindo a imagem:
#
# <img src="images/branch github.png"  alt="Branch GitHub" width=200>
#
# Percebeu como a nova branch é exatamente igual sua raíz? Agora você sabe como utilizar diferentes ramos para diferentes propósitos!
#
# **Ao mudar de branch no GitHub Desktop, o PyCharm e o VS Code também mudam instantaneamente, alterando todos os códigos e arquivos! Experimente mudar o mesmo código em branchs diferentes e realizar a troca.** As branches também podem ser alternadas diretamente no IDE, na parte de baixo.
#
# #### 10.4 Realizando o merge de branchs
# Desenvolva diferentes tipos de códigos, realize quaisquer mudanças em duas ou mais branches pois agora vamos testar como funciona o **merge**.
#
# Para isso, no GitHub Desktop vá para a branch em que será feita o _merge_. Aqui eu vou realizar direto na master!
#
# Vá até a aba Branch e selecione _Merge into current branch_. Selecione a _branch_ filha. Se não houverem conflitos, os códigos e arquivos já estarão juntos! Falta agora realizar o último _commit_ e o _push_!
#
# Se quiser realizar o _merge_ pelo IDE:
# 1. No **VS Code**, clique na opção de branch abaixo e aperte _Ctrl + Shift + P_. No campo que abriu, procure Git: Merge branch e selecione a opção.
# 2. No PyCharm, na barra de cima acesse as abas VCS > Git > Merge Changes.
#
# PyCharm Merge            |  VS Code Merge
# :-------------------------:|:-------------------------:
# <img src="images/pycharm merge.png"  alt="PyCharm Merge" width=400/> | <img src="images/vscode merge.png"  alt="VS Code Merge" width=450/>

# %% [markdown]
# ### 11. Issues, o que são e como usar?
# No GitHub, cada repositório possui uma sessão de _Issues_. É lá que podemos contribuir em projetos de outros usuários, além de tirar dúvidas com o próprio dono do repositório. Você pode:
# - Criar issues perguntando sobre o funcionamento ou reportando um erro de instalação ou bug ao utilizar algo do repositório;
# - Comentar nas próprias _issues_ e nas dos outros, para contribuir com uma solução ou reportar um erro parecido;
# - Realizar um _request_ (pedido) para o projeto em si que ache importante;
# - Se você for o desenvolvedor, pode também criar _issues_ pedindo que os usuários te ajudem;
# - Como dono do repositório, pode realizar o _pin_ (fixar) uma _issue_ no início (ex: seus próprios pedidos, ou as _issues_ que mais precisam ser resolvidas);
# - Também consegue transferir uma _issue_ para outro projeto, se for condizente ao mesmo;
# - Adicionar texto, imagens, vídeos, pedaços de código, links.
#
# Para acessar e criar uma _issue_ é só seguir os 2 passos na imagem abaixo. Visite algum repositório que já te ajudou em algo, acesse a aba _Issues_ e poderá ver se alguém precisa de ajuda. Se você passou pela mesma situação e conseguiu resolver, contribuir com essa _issue_ será importante para você, para quem perguntou e para o próprio desenvolvedor!
#
# **ATENÇÃO!:** Não crie uma _issue_ sem antes pesquisar se alguém já teve o mesmo problema que você. O nome disso é _flood_. Faça primeiro uma busca. Se encontrar a solução, agradeça na _issue_ já criada para que mais pessoas vejam e para que o ambiente fique mais limpo. Alguns repositórios possuem **milhares de _issues_**.
#
# Dependendo do número de _issues_, elas podem ser administradas pelo dono do repositório. Sendo assim, elas podem ser fechadas (porém ainda assim estarão disponíveis para consulta).
#
# <img src="images/github issues.png"  alt="GitHub Issues" width=600/>

# %% [markdown]
# ### 12. Fork: a melhor forma de contribuir para o código
# Os _issues_ servem muito bem para aqueles que possuem alguma dúvida, pedido especial ou querem relatar bugs que não sabem como resolver.
#
# Se você já utilizou o repositório de alguém, constatou um bug e **conseguiu solucioná-lo**, ou se fez algum tipo de melhoria, a _issue_ **não é a sessão para isso**. Vamos nesse caso utilizar o sistema de **fork**.
#
# ### 13. Segurança: Autenticação em duas etapas
# Com o tempo e uso, seu GitHub se torna cada vez mais importante. É possível que ele seja o **único** lugar em que seus projetos estão salvos. Sendo assim, como torná-lo mais seguro?
#
# #### 13.1 Armazene em locais diversos
# Primeiramente, devemos sempre salvar nossas versões de projeto em outro local: HD externo, em serviços de armazenamento em nuvem (Google Drive, Dropbox, etc) ou até mesmo em outros sistemas de repositório integrado ao Git, como o GitLab. Isso é questão de **segurança**.
#
# #### 13.2 Utilize senhas fortes
# Isso serve para todos os sites e aplicativos. Eu sei que você usa **a mesma** senha em alguns de seus logins. Se for repeti-la, ao menos utilize uma senha forte. As três características abaixo já bastam:
# 1. mais de 8 caracteres;
# 2. letras, números e símbolos;
# 3. não utilizar seu nome ou apelido.
#
# Hoje em dia existem aplicativos que cuidam de nossas senhas com muita segurança. Se você for utilizar algum desses, considere não repetir nenhuma senha. Se alguém tiver acesso a uma dessas senhas, não conseguirá invadir mais nenhum outro local. O mesmo não é verdade para aqueles que utilizam a mesma senha em diversas plataformas.
#
# https://www.youtube.com/watch?v=bsI6P_IM_hg&list=PLHz_AreHm4dm7ZULPAmadvNhH6vk9oNZA&index=11&ab_channel=CursoemV%C3%ADdeo
#
# #### 13.3 Autenticação em duas etapas
# Essa é uma das formas mais seguras e utilizadas de segurança: A autenticação em duas etapas. Isso porque, além de precisar de seu login e senha, ainda é adicionado um segundo método para confirmar que realmente é você quem está acessando a plataforma.
#
# Em seu GitHub, clique em seu ícone de perfil, vá em _Settings_, clique na aba _Security_ ao lado esquerdo e procure a opção _Two-factor authentication_.
#
# Aqui, você poderá escolher se autenticará através de um aplicativo ou via um código de SMS (por enquanto não existe para números brasileiros). Felizmente, a primeira opção é mais segura, pois somente você possui acesso ao celular, que está protegido também por uma senha.
# Ao escolher a forma de autenticação, **guarde os tokens de segurança que apareceram na tela**. Você pode guardá-los nos mesmos locais da sessão 12.1.
#
# Em seu smartphone, busque pelo aplicativo **Google Authenticator**. No aplicativo, autorize o acesso à câmera de seu celular, clique em _ler código de barras_ e aponte para o QRcode mostrado em seu GitHub. Aparecerá um código de 6 dígitos. Digite-os em seu GitHub no campo referente.
#
# Pronto! Em todas suas tentativas de login em sua conta do GitHub, precisará confirmar através do aplicativo Google Authenticator. Recomendo utilizá-lo para seus logins do Google e para outros sites que permitam autenticação por aplicativo.

# %% [markdown]
# ## 14. GitHub como Portfólio
# Agora que você já sabe como utilizar o sistema Git integrado ao GitHub, já deve estar planejando ou até mesmo desenvolvendo projetos em repositório. Chegou a hora de deixar o seu perfil mais descritivo a quem te visita! Vamos fazer por etapas:
# 1. Clique no ícone de perfil, do lado direito superior e vá até Settings;
# 2. Na aba Profile, coloque seu nome e sobrenome reais, e adicione uma foto profissional para o perfil;
# 3. No campo Bio, dê uma pequena descrição do que você está estudando ou da qualificação que possui;
# 4. Mais abaixo, você pode marcar "Include private contributions on my profile" para que os repositórios privados também sejam contabilizados em seus acessos ao GitHub.
# 5. Na mesma página, em Jobs Profile, selecione "Available for hire" se deseja ser contratado
#
# Se você visitou meu perfil, se deparou com a minha descrição como indicado na imagem abaixo:
#
# <img src="images/overview github.png"  alt="Overview GitHub" width=600/>
#
# Siga as etapas abaixo para criar um parecido!
# 1. Crie um repositório com o **mesmo** nome de seu perfil. No meu caso, o repositório ficou assim: https://github.com/dantebarross/dantebarross;
# 2. Habilite a opção de README, pois é nesse arquivo que escreverá sua descrição;
# 3. Após criado o repositório, sua página de perfil conterá o texto padrão do README;
# 4. Entre no repositório e edite o arquivo README. Utilize a formatação Markdown para criar títulos, inserir elementos HTML, GIFs, utilize a criatividade!
#
# ## 14.1 Crie sua página web com o GitHub Pages
# Com o GitHub Pages, podemos facilmente e gratuitamente criar uma página sua para utilizar como porta de entrada para seu portfólio, ou como um link para mostrar de forma mais interativa seus trabalhos.
#
# O GitHub Pages possui templates prontos para você escolher, mas uma outra possibilidade é utilizar templates externos ou até mesmo criar o seu próprio, demonstrando habilidades de HTML, CSS e Javascript! Existe até mesmo a possibilidade de utilizá-lo como blog com uma ferramenta especial. Outra possibilidade é hospedar os seus sites já desenvolvidos.
#
# Acesse o site https://pages.github.com/ para se aprofundar. Aqui, vamos dar um passo a passo para te ajudar a criar a página em sua forma básica:
# 1. Crie um repositório no GitHub para os arquivos de sua página web. Se já possuir uma, coloque os arquivos no repositório remoto através do método de sua preferência;
# 2. Dentro do repositório no GitHub, clique em Settings e desça até encontrar a opção GitHub Pages;
# 3. Em Source, escolha a branch de sua página;
# 4. Caso ainda não tenha desenvolvido seu website, escolha um tema em Theme Chooser.
#
# **ATENÇÃO**: Ao tornar o repositório privado, sua GitHub Page não estará mais disponível para acesso.
#
# Pronto! Você possui uma página web para mostrar seu trabalho e treinar seus conhecimentos. Recomendo criar um repositório e página de apresentação com o mesmo nome do perfil. No meu caso, essa página ficou com a URL http://dantebarross.github.io/.
